# %% [markdown]
# ## 1. Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.utils import to_categorical
import numpy as np

# %% [markdown]
# ## 2. Load MNIST Dataset

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Convert labels to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# %% [markdown]
# ## 3. Create Model

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(10, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='sigmoid')  # Use sigmoid in the output layer
])

adam=Adam(learning_rate=0.001)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',  # Use categorical_crossentropy for one-hot labels
              metrics=['accuracy'])
# Out:
# /home/reza/.local/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## 4. Train Model

# %%
history = model.fit(train_images, train_labels_one_hot, epochs=15, batch_size=32, validation_data=(test_images, test_labels_one_hot))

# Evaluate the model
loss, accuracy = model.evaluate(test_images, test_labels_one_hot)
print(f"Test accuracy: {accuracy * 100:.2f}%")

weights = model.get_weights()
# Out:
# Epoch 1/15
#  159/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - accuracy: 0.7895 - loss: 0.6296
# 2024-10-25 15:04:26.939165: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7843 - loss: 0.6390 - val_accuracy: 0.9131 - val_loss: 0.3190
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7831 - loss: 0.6455 - val_accuracy: 0.9151 - val_loss: 0.3092
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7833 - loss: 0.6466 - val_accuracy: 0.9136 - val_loss: 0.3223
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7827 - loss: 0.6383 - val_accuracy: 0.9132 - val_loss: 0.3123
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7841 - loss: 0.6367 - val_accuracy: 0.9128 - val_loss: 0.3151
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7826 - loss: 0.6386 - val_accuracy: 0.9156 - val_loss: 0.3141
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7856 - loss: 0.6367 - val_accuracy: 0.9142 - val_loss: 0.3078
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7825 - loss: 0.6389 - val_accuracy: 0.9141 - val_loss: 0.3127
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7847 - loss: 0.6352 - val_accuracy: 0.9134 - val_loss: 0.3116
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7876 - loss: 0.6262 - val_accuracy: 0.9142 - val_loss: 0.3058
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7850 - loss: 0.6379 - val_accuracy: 0.9118 - val_loss: 0.3112
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7861 - loss: 0.6293 - val_accuracy: 0.9079 - val_loss: 0.3254
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7859 - loss: 0.6366 - val_accuracy: 0.9089 - val_loss: 0.3172
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7893 - loss: 0.6259 - val_accuracy: 0.9096 - val_loss: 0.3210
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7915 - loss: 0.6167 - val_accuracy: 0.9090 - val_loss: 0.3224
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.8982 - loss: 0.3601
# Test accuracy: 90.90%

# %% [markdown]
# ## 5. Utils Function

# %% [markdown]
# ### 5.1. Save Raw Weights

# %%
def save_model_weights_to_file(model, filename):
    with open(filename, 'w') as file:
        for layer_idx, layer in enumerate(model.layers):
            # Check if the layer has weights (e.g., Dense layers)
            if(len(layer.get_weights()) > 0):
                weights, biases = layer.get_weights()

                # Iterate over the weights matrix
                for i in range(weights.shape[0]):  # Iterate over neurons in the current layer
                    for j in range(weights.shape[1]):  # Iterate over neurons in the next layer
                        weight_value = weights[i, j]
                        # Write the weight information to the file
                        file.write(f"In layer {layer_idx}, neuron {i} is connected to neuron {j} in the next layer with weight value: {weight_value}\n")


save_model_weights_to_file(model, 'model_weights.txt')

# %% [markdown]
# ### 5.2. Extract All Weights

# %%
def extract_weights(model, filename):
    with open(filename, 'w') as file:
        for layer_idx, layer in enumerate(model.layers):
            # Check if the layer has weights (e.g., Dense layers)
            if(len(layer.get_weights()) > 0):
                weights, biases = layer.get_weights()

                # Iterate over the weights matrix
                for i in range(weights.shape[0]):  # Iterate over neurons in the current layer
                    for j in range(weights.shape[1]):  # Iterate over neurons in the next layer
                        weight_value = weights[i, j]
                        # Write the weight information to the file
                        file.write(str(weight_value)+"\n")


extract_weights(model, 'pure_weights.txt')

# %% [markdown]
# ## 6. Select Random Input and Their Predict and Trure Label for Test in Inference Phase on FPGA

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

test_images = test_images / 255.0

np.random.seed(0)
random_idxs = np.random.choice(test_images.shape[0], 200, replace=False)
selected_images = test_images[random_idxs]
selected_labels = test_labels[random_idxs]

selected_images = np.expand_dims(selected_images, axis=-1) 

predictions = model.predict(selected_images)

predicted_classes = np.argmax(predictions, axis=1)

for i, (pred, true) in enumerate(zip(predicted_classes, selected_labels)):
  print(f"Image {i+1}: Predicted class = {pred}, True class = {true}"+'\n')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Image 1: Predicted class = 8, True class = 8
#
# Image 2: Predicted class = 8, True class = 7
#
# Image 3: Predicted class = 1, True class = 1
#
# Image 4: Predicted class = 9, True class = 7
#
# Image 5: Predicted class = 1, True class = 1
#
# Image 6: Predicted class = 2, True class = 2
#
# Image 7: Predicted class = 1, True class = 1
#
# Image 8: Predicted class = 9, True class = 9
#
# Image 9: Predicted class = 0, True class = 5
#
# Image 10: Predicted class = 4, True class = 4
#
# Image 11: Predicted class = 5, True class = 5
#
# Image 12: Predicted class = 6, True class = 6
#
# Image 13: Predicted class = 3, True class = 3
#
# Image 14: Predicted class = 2, True class = 2
#
# Image 15: Predicted class = 0, True class = 0
#
# Image 16: Predicted class = 7, True class = 7
#
# Image 17: Predicted class = 6, True class = 6
#
# Image 18: Predicted class = 4, True class = 4
#
# Image 19: Predicted class = 6, True class = 6
#
# Image 20: Predicted class = 4, True class = 4
#
# Image 21: Predicted class = 3, True class = 5
#
# Image 22: Predicted class = 9, True class = 7
#
# Image 23: Predicted class = 6, True class = 8
#
# Image 24: Predicted class = 4, True class = 9
#
# Image 25: Predicted class = 8, True class = 8
#
# Image 26: Predicted class = 7, True class = 7
#
# Image 27: Predicted class = 4, True class = 4
#
# Image 28: Predicted class = 3, True class = 3
#
# Image 29: Predicted class = 9, True class = 9
#
# Image 30: Predicted class = 4, True class = 4
#
# Image 31: Predicted class = 2, True class = 2
#
# Image 32: Predicted class = 2, True class = 2
#
# Image 33: Predicted class = 9, True class = 9
#
# Image 34: Predicted class = 7, True class = 7
#
# Image 35: Predicted class = 6, True class = 6
#
# Image 36: Predicted class = 7, True class = 7
#
# Image 37: Predicted class = 1, True class = 1
#
# Image 38: Predicted class = 2, True class = 2
#
# Image 39: Predicted class = 8, True class = 8
#
# Image 40: Predicted class = 5, True class = 3
#
# Image 41: Predicted class = 0, True class = 0
#
# Image 42: Predicted class = 6, True class = 6
#
# Image 43: Predicted class = 4, True class = 4
#
# Image 44: Predicted class = 0, True class = 0
#
# Image 45: Predicted class = 8, True class = 8
#
# Image 46: Predicted class = 7, True class = 7
#
# Image 47: Predicted class = 4, True class = 8
#
# Image 48: Predicted class = 2, True class = 2
#
# Image 49: Predicted class = 9, True class = 9
#
# Image 50: Predicted class = 0, True class = 0
#
# Image 51: Predicted class = 4, True class = 4
#
# Image 52: Predicted class = 3, True class = 3
#
# Image 53: Predicted class = 4, True class = 4
#
# Image 54: Predicted class = 0, True class = 0
#
# Image 55: Predicted class = 7, True class = 7
#
# Image 56: Predicted class = 0, True class = 0
#
# Image 57: Predicted class = 7, True class = 7
#
# Image 58: Predicted class = 4, True class = 4
#
# Image 59: Predicted class = 6, True class = 6
#
# Image 60: Predicted class = 1, True class = 1
#
# Image 61: Predicted class = 9, True class = 9
#
# Image 62: Predicted class = 7, True class = 7
#
# Image 63: Predicted class = 2, True class = 2
#
# Image 64: Predicted class = 8, True class = 8
#
# Image 65: Predicted class = 5, True class = 8
#
# Image 66: Predicted class = 0, True class = 0
#
# Image 67: Predicted class = 1, True class = 1
#
# Image 68: Predicted class = 0, True class = 0
#
# Image 69: Predicted class = 5, True class = 5
#
# Image 70: Predicted class = 1, True class = 1
#
# Image 71: Predicted class = 5, True class = 5
#
# Image 72: Predicted class = 1, True class = 1
#
# Image 73: Predicted class = 4, True class = 4
#
# Image 74: Predicted class = 9, True class = 9
#
# Image 75: Predicted class = 4, True class = 4
#
# Image 76: Predicted class = 8, True class = 8
#
# Image 77: Predicted class = 7, True class = 7
#
# Image 78: Predicted class = 2, True class = 3
#
# Image 79: Predicted class = 7, True class = 7
#
# Image 80: Predicted class = 8, True class = 8
#
# Image 81: Predicted class = 9, True class = 9
#
# Image 82: Predicted class = 1, True class = 1
#
# Image 83: Predicted class = 4, True class = 4
#
# Image 84: Predicted class = 4, True class = 4
#
# Image 85: Predicted class = 0, True class = 0
#
# Image 86: Predicted class = 2, True class = 2
#
# Image 87: Predicted class = 5, True class = 5
#
# Image 88: Predicted class = 7, True class = 7
#
# Image 89: Predicted class = 7, True class = 7
#
# Image 90: Predicted class = 5, True class = 5
#
# Image 91: Predicted class = 3, True class = 3
#
# Image 92: Predicted class = 0, True class = 0
#
# Image 93: Predicted class = 6, True class = 6
#
# Image 94: Predicted class = 2, True class = 2
#
# Image 95: Predicted class = 4, True class = 4
#
# Image 96: Predicted class = 1, True class = 1
#
# Image 97: Predicted class = 6, True class = 6
#
# Image 98: Predicted class = 8, True class = 8
#
# Image 99: Predicted class = 6, True class = 6
#
# Image 100: Predicted class = 9, True class = 9
#
# Image 101: Predicted class = 3, True class = 3
#
# Image 102: Predicted class = 3, True class = 3
#
# Image 103: Predicted class = 0, True class = 0
#
# Image 104: Predicted class = 3, True class = 3
#
# Image 105: Predicted class = 6, True class = 6
#
# Image 106: Predicted class = 6, True class = 6
#
# Image 107: Predicted class = 4, True class = 4
#
# Image 108: Predicted class = 8, True class = 8
#
# Image 109: Predicted class = 8, True class = 8
#
# Image 110: Predicted class = 7, True class = 7
#
# Image 111: Predicted class = 4, True class = 4
#
# Image 112: Predicted class = 6, True class = 6
#
# Image 113: Predicted class = 3, True class = 3
#
# Image 114: Predicted class = 6, True class = 6
#
# Image 115: Predicted class = 0, True class = 0
#
# Image 116: Predicted class = 4, True class = 4
#
# Image 117: Predicted class = 8, True class = 8
#
# Image 118: Predicted class = 5, True class = 5
#
# Image 119: Predicted class = 7, True class = 7
#
# Image 120: Predicted class = 8, True class = 8
#
# Image 121: Predicted class = 0, True class = 6
#
# Image 122: Predicted class = 7, True class = 7
#
# Image 123: Predicted class = 1, True class = 5
#
# Image 124: Predicted class = 0, True class = 5
#
# Image 125: Predicted class = 1, True class = 1
#
# Image 126: Predicted class = 0, True class = 0
#
# Image 127: Predicted class = 7, True class = 7
#
# Image 128: Predicted class = 4, True class = 4
#
# Image 129: Predicted class = 5, True class = 5
#
# Image 130: Predicted class = 6, True class = 6
#
# Image 131: Predicted class = 5, True class = 5
#
# Image 132: Predicted class = 9, True class = 9
#
# Image 133: Predicted class = 1, True class = 1
#
# Image 134: Predicted class = 4, True class = 4
#
# Image 135: Predicted class = 4, True class = 4
#
# Image 136: Predicted class = 9, True class = 9
#
# Image 137: Predicted class = 4, True class = 4
#
# Image 138: Predicted class = 5, True class = 5
#
# Image 139: Predicted class = 4, True class = 4
#
# Image 140: Predicted class = 8, True class = 8
#
# Image 141: Predicted class = 9, True class = 9
#
# Image 142: Predicted class = 8, True class = 8
#
# Image 143: Predicted class = 6, True class = 6
#
# Image 144: Predicted class = 7, True class = 7
#
# Image 145: Predicted class = 8, True class = 8
#
# Image 146: Predicted class = 2, True class = 2
#
# Image 147: Predicted class = 1, True class = 1
#
# Image 148: Predicted class = 1, True class = 1
#
# Image 149: Predicted class = 1, True class = 1
#
# Image 150: Predicted class = 4, True class = 4
#
# Image 151: Predicted class = 9, True class = 9
#
# Image 152: Predicted class = 4, True class = 4
#
# Image 153: Predicted class = 8, True class = 8
#
# Image 154: Predicted class = 3, True class = 3
#
# Image 155: Predicted class = 4, True class = 4
#
# Image 156: Predicted class = 0, True class = 0
#
# Image 157: Predicted class = 3, True class = 3
#
# Image 158: Predicted class = 4, True class = 4
#
# Image 159: Predicted class = 5, True class = 5
#
# Image 160: Predicted class = 9, True class = 9
#
# Image 161: Predicted class = 9, True class = 9
#
# Image 162: Predicted class = 4, True class = 4
#
# Image 163: Predicted class = 7, True class = 7
#
# Image 164: Predicted class = 5, True class = 5
#
# Image 165: Predicted class = 0, True class = 0
#
# Image 166: Predicted class = 0, True class = 0
#
# Image 167: Predicted class = 1, True class = 1
#
# Image 168: Predicted class = 6, True class = 6
#
# Image 169: Predicted class = 9, True class = 9
#
# Image 170: Predicted class = 9, True class = 9
#
# Image 171: Predicted class = 9, True class = 7
#
# Image 172: Predicted class = 8, True class = 8
#
# Image 173: Predicted class = 2, True class = 7
#
# Image 174: Predicted class = 6, True class = 6
#
# Image 175: Predicted class = 2, True class = 4
#
# Image 176: Predicted class = 1, True class = 1
#
# Image 177: Predicted class = 0, True class = 0
#
# Image 178: Predicted class = 2, True class = 2
#
# Image 179: Predicted class = 8, True class = 8
#
# Image 180: Predicted class = 3, True class = 3
#
# Image 181: Predicted class = 1, True class = 1
#
# Image 182: Predicted class = 2, True class = 2
#
# Image 183: Predicted class = 4, True class = 4
#
# Image 184: Predicted class = 8, True class = 8
#
# Image 185: Predicted class = 3, True class = 3
#
# Image 186: Predicted class = 8, True class = 8
#
# Image 187: Predicted class = 4, True class = 4
#
# Image 188: Predicted class = 0, True class = 0
#
# Image 189: Predicted class = 9, True class = 9
#
# Image 190: Predicted class = 2, True class = 2
#
# Image 191: Predicted class = 1, True class = 7
#
# Image 192: Predicted class = 8, True class = 8
#
# Image 193: Predicted class = 6, True class = 6
#
# Image 194: Predicted class = 2, True class = 2
#
# Image 195: Predicted class = 2, True class = 2
#
# Image 196: Predicted class = 1, True class = 1
#
# Image 197: Predicted class = 3, True class = 3
#
# Image 198: Predicted class = 1, True class = 1
#
# Image 199: Predicted class = 6, True class = 6
#
# Image 200: Predicted class = 2, True class = 2
